# %% [markdown]
# # INITIAL DATA EXPLORATION
#
# *   Load the dataset
# *   Check for data types
# *   Check for missing values
# *   Check for duplicative rows

# %%
import pandas as pd

# %%
df = pd.read_csv('creditcard.csv')

# %%
# Inspect the structure of the dataset
# Display the first few rows of the dataset
print("First five rows of the dataset:")
display(df.head())
# Out:
# First five rows of the dataset:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
# Check the columns and their data types
print("\nColumn Information:")
df.info()
# Out:
# Column Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
# ...

# %%
# Check for relevant columns: 'Time', 'Amount', 'Class', and PCA components 'V1' to 'V28'
required_columns = ['Time', 'Amount', 'Class'] + [f'V{i}' for i in range(1, 29)]
missing_columns = [col for col in required_columns if col not in df.columns]
if not missing_columns:
    print("\nAll required columns are present in the dataset.")
else:
    print(f"\nWarning: The following required columns are missing: {missing_columns}")
# Out:
# All required columns are present in the dataset.

# %%
# Check for data quality issues
# Check for missing values
print("\nMissing Values in Each Column:")
print(df.isnull().sum())
# Out:
# Missing Values in Each Column:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# Basic descriptive statistics to check data ranges and detect any outliers
print("\nBasic Descriptive Statistics:")
display(df.describe())
# Out:
# Basic Descriptive Statistics:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
# Check for duplicate rows
duplicates = df.duplicated().sum()
print(f"\nNumber of duplicate rows: {duplicates}")
# Out:
# Number of duplicate rows: 1081

# %% [markdown]
# ## EXPLORATORY DATA ANALYSIS

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print("First five rows of the dataset:")
display(df.head())
# Out:
# First five rows of the dataset:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
# Check the columns and their data types
print("\nColumn Information:")
df.info()
# Out:
# Column Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
# ...

# %%
# Check for relevant columns: 'Time', 'Amount', 'Class', and PCA components 'V1' to 'V28'
required_columns = ['Time', 'Amount', 'Class'] + [f'V{i}' for i in range(1, 29)]
missing_columns = [col for col in required_columns if col not in df.columns]
if not missing_columns:
    print("\nAll required columns are present in the dataset.")
else:
    print(f"\nWarning: The following required columns are missing: {missing_columns}")
# Out:
# All required columns are present in the dataset.

# %%
# Check for data quality issues
# Check for missing values
print("\nMissing Values in Each Column:")
print(df.isnull().sum())
# Out:
# Missing Values in Each Column:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# Basic descriptive statistics to check data ranges and detect any outliers
print("\nBasic Descriptive Statistics:")
display(df.describe())
# Out:
# Basic Descriptive Statistics:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
# Check for duplicate rows
duplicates = df.duplicated().sum()
print(f"\nNumber of duplicate rows: {duplicates}")
# Out:
# Number of duplicate rows: 1081

# %%
# EDA Part 1: Class Distribution Analysis
class_counts = df['Class'].value_counts()
print("\nClass Distribution (Non-Fraud vs. Fraud):\n", class_counts)
# Out:
# Class Distribution (Non-Fraud vs. Fraud):
#  Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
# Plot the class distribution
plt.figure(figsize=(10, 8))
sns.countplot(x='Class', data=df, palette=['#3498db', '#e74c3c'])
plt.title('Class Distribution (Non-Fraud vs. Fraud)')
plt.xlabel('Class (0: Non-Fraud, 1: Fraud)')
plt.ylabel('Count')
plt.show()
# Out:
# <ipython-input-129-5529b6da3d77>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Class', data=df, palette=['#3498db', '#e74c3c'])

# %%
# EDA Part 2: Basic Descriptive Statistics by Class
# Calculate descriptive statistics for 'Time' and 'Amount' by Class (fraud vs. non-fraud)
stats_class = df.groupby('Class')[['Time', 'Amount']].agg(['mean', 'median', 'std'])
print("\nDescriptive Statistics for 'Time' and 'Amount' by Class:\n", stats_class)
# Out:
# Descriptive Statistics for 'Time' and 'Amount' by Class:
#                 Time                             Amount
#                mean   median           std        mean median         std
# Class
# 0      94838.202258  84711.0  47484.015786   88.291022  22.00  250.105092
# 1      80746.806911  75568.5  47835.365138  122.211321   9.25  256.683288

# %%
# Visualize the distribution of 'Time'
plt.figure(figsize=(12, 5))
sns.histplot(df['Time'], bins=50, kde=True, color='skyblue')
plt.title('Distribution of Transaction Time')
plt.xlabel('Time (seconds elapsed from the first transaction)')
plt.ylabel('Frequency')
plt.show()

# %%
# Visualize the distribution of 'Amount' for fraud and non-fraud transactions
plt.figure(figsize=(12, 5))
sns.histplot(df[df['Class'] == 0]['Amount'], bins=50, kde=True, color='blue', label='Non-Fraud')
sns.histplot(df[df['Class'] == 1]['Amount'], bins=50, kde=True, color='red', label='Fraud')
plt.title('Distribution of Transaction Amount (Fraud vs. Non-Fraud)')
plt.xlabel('Transaction Amount')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
# Additional Analysis: Correlation Heatmap for PCA Components and Key Variables
plt.figure(figsize=(15, 10))
corr_matrix = df.corr()
sns.heatmap(corr_matrix, annot=False, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap of PCA Components, 'Time', 'Amount', and 'Class'")
plt.show()

# %% [markdown]
# # TRANSACTION TIME PATTERN ANALYSIS

# %%
# Convert 'Time' into hours
df['Hour'] = (df['Time'] // 3600) % 24  # Convert seconds to hours

# %%
# --- Time Segmentation ---

# Segment into day vs. night
df['TimeOfDay'] = df['Hour'].apply(lambda x: 'Day' if 6 <= x < 18 else 'Night')

# Segment into business vs. non-business hours (assuming business hours are 9 AM to 5 PM)
df['BusinessHours'] = df['Hour'].apply(lambda x: 'Business Hours' if 9 <= x < 17 else 'Non-Business Hours')

# %%
# --- Visualization ---

# 1. Transaction Count by Hour for Fraud and Non-Fraud Cases
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='Hour', hue='Class', palette=['#3498db', '#e74c3c'])
plt.title('Transaction Count by Hour (Fraud vs. Non-Fraud)')
plt.xlabel('Hour of the Day')
plt.ylabel('Transaction Count')
plt.legend(['Non-Fraud', 'Fraud'])
plt.show()

# %%
# 2. Day vs. Night Transaction Frequency for Fraud and Non-Fraud Cases
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='TimeOfDay', hue='Class', palette=['#3498db', '#e74c3c'])
plt.title('Day vs. Night Transaction Count (Fraud vs. Non-Fraud)')
plt.xlabel('Time of Day')
plt.ylabel('Transaction Count')
plt.legend(['Non-Fraud', 'Fraud'])
plt.show()

# %%
# 3. Business Hours vs. Non-Business Hours Transaction Frequency for Fraud and Non-Fraud Cases
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='BusinessHours', hue='Class', palette=['#3498db', '#e74c3c'])
plt.title('Business vs. Non-Business Hours Transaction Count (Fraud vs. Non-Fraud)')
plt.xlabel('Time Segment')
plt.ylabel('Transaction Count')
plt.legend(['Non-Fraud', 'Fraud'])
plt.show()

# %%
# 4. Time-based Heatmap for Fraud and Non-Fraud Transactions
# Create a pivot table for a heatmap with hours and fraud indicator
hourly_fraud_counts = df.pivot_table(index='Hour', columns='Class', values='Amount', aggfunc='count').fillna(0)
hourly_fraud_counts.columns = ['Non-Fraud', 'Fraud']

plt.figure(figsize=(12, 6))
sns.heatmap(hourly_fraud_counts, annot=True, fmt=".0f", cmap="Blues", linewidths=0.5)
plt.title('Hourly Fraud and Non-Fraud Transaction Heatmap')
plt.xlabel('Transaction Type')
plt.ylabel('Hour of the Day')
plt.show()

# %%
# Class Distribution Analysis
class_counts = df['Class'].value_counts()
total_transactions = class_counts.sum()
fraud_percentage = (class_counts[1] / total_transactions) * 100
non_fraud_percentage = (class_counts[0] / total_transactions) * 100

print("Class Distribution Analysis:")
print(f"Total Transactions: {total_transactions}")
print(f"Fraudulent Transactions: {class_counts[1]} ({fraud_percentage:.2f}%)")
print(f"Non-Fraudulent Transactions: {class_counts[0]} ({non_fraud_percentage:.2f}%)\n")
# Out:
# Class Distribution Analysis:
# Total Transactions: 284807
# Fraudulent Transactions: 492 (0.17%)
# Non-Fraudulent Transactions: 284315 (99.83%)

# %%
# Descriptive Statistics by Class
stats_class = df.groupby('Class')[['Time', 'Amount']].agg(['mean', 'median', 'std'])
print("Descriptive Statistics for 'Time' and 'Amount' by Class:")
print(stats_class, "\n")
# Out:
# Descriptive Statistics for 'Time' and 'Amount' by Class:
#                Time                             Amount
#                mean   median           std        mean median         std
# Class
# 0      94838.202258  84711.0  47484.015786   88.291022  22.00  250.105092
# 1      80746.806911  75568.5  47835.365138  122.211321   9.25  256.683288

# %%
# Transaction Count by Hour for Fraud and Non-Fraud Cases
hourly_counts = df.groupby(['Hour', 'Class']).size().unstack(fill_value=0)
print("Transaction Count by Hour (Fraud vs. Non-Fraud):")
print(hourly_counts, "\n")
# Out:
# Transaction Count by Hour (Fraud vs. Non-Fraud):
# Class      0   1
# Hour
# 0.0     7689   6
# 1.0     4210  10
# 2.0     3271  57
# 3.0     3475  17
# 4.0     2186  23
# 5.0     2979  11
# 6.0     4092   9
# 7.0     7220  23
# 8.0    10267   9
# 9.0    15822  16
# 10.0   16590   8
# 11.0   16803  53
# 12.0   15403  17
# 13.0   15348  17
# 14.0   16547  23
# 15.0   16435  26
# 16.0   16431  22
# 17.0   16137  29
# 18.0   17006  33
# 19.0   15630  19
# 20.0   16738  18
# 21.0   17687  16
# 22.0   15432   9
# 23.0   10917  21

# %%
# Day vs. Night Transaction Frequency for Fraud and Non-Fraud Cases
time_of_day_counts = df.groupby(['TimeOfDay', 'Class']).size().unstack(fill_value=0)
print("Day vs. Night Transaction Count (Fraud vs. Non-Fraud):")
print(time_of_day_counts, "\n")
# Out:
# Day vs. Night Transaction Count (Fraud vs. Non-Fraud):
# Class           0    1
# TimeOfDay
# Day        167095  252
# Night      117220  240

# %%
# Business Hours vs. Non-Business Hours Transaction Frequency for Fraud and Non-Fraud Cases
business_hours_counts = df.groupby(['BusinessHours', 'Class']).size().unstack(fill_value=0)
print("Business vs. Non-Business Hours Transaction Count (Fraud vs. Non-Fraud):")
print(business_hours_counts, "\n")
# Out:
# Business vs. Non-Business Hours Transaction Count (Fraud vs. Non-Fraud):
# Class                    0    1
# BusinessHours
# Business Hours      129379  182
# Non-Business Hours  154936  310

# %%
# Hourly Fraud and Non-Fraud Transaction Counts
hourly_fraud_counts = df.pivot_table(index='Hour', columns='Class', values='Amount', aggfunc='count').fillna(0)
hourly_fraud_counts.columns = ['Non-Fraud', 'Fraud']
print("Hourly Fraud and Non-Fraud Transaction Counts:")
print(hourly_fraud_counts)
# Out:
# Hourly Fraud and Non-Fraud Transaction Counts:
#       Non-Fraud  Fraud
# Hour
# 0.0        7689      6
# 1.0        4210     10
# 2.0        3271     57
# 3.0        3475     17
# 4.0        2186     23
# 5.0        2979     11
# 6.0        4092      9
# 7.0        7220     23
# 8.0       10267      9
# 9.0       15822     16
# 10.0      16590      8
# 11.0      16803     53
# 12.0      15403     17
# 13.0      15348     17
# 14.0      16547     23
# 15.0      16435     26
# 16.0      16431     22
# 17.0      16137     29
# 18.0      17006     33
# 19.0      15630     19
# 20.0      16738     18
# 21.0      17687     16
# 22.0      15432      9
# 23.0      10917     21

# %% [markdown]
# # TRANSACTION AMOUNT ANALYSIS

# %%
# Amount Segmentation: Create bins for transaction amounts
bins = [0, 50, 100, 200, 500, 1000, 5000]  # Define the bins
labels = ['Close to None', 'Very Low', 'Low', 'Medium', 'High', 'Very High']  # Define labels for the bins
df['AmountCategory'] = pd.cut(df['Amount'], bins=bins, labels=labels, right=False)  # Adjust labels to match bins

# %%
# Calculate fraud rates within each amount bin
fraud_rates = df.groupby('AmountCategory')['Class'].mean() * 100  # Mean gives the fraud rate in percentage

print("Fraud Rates within Each Amount Bin:")
print(fraud_rates)
# Out:
# Fraud Rates within Each Amount Bin:
# AmountCategory
# Close to None    0.160777
# Very Low         0.151121
# Low              0.160314
# Medium           0.252232
# High             0.404795
# Very High        0.298607
# Name: Class, dtype: float64
# <ipython-input-147-1f8587773959>:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   fraud_rates = df.groupby('AmountCategory')['Class'].mean() * 100  # Mean gives the fraud rate in percentage

# %%
# Visualization: Plot fraud and non-fraud distributions within each amount bin

# Box Plot: Amount distribution by Class within each bin
plt.figure(figsize=(12, 6))
sns.boxplot(x='AmountCategory', y='Amount', hue='Class', data=df, palette=['#3498db', '#e74c3c'])
plt.title('Transaction Amount Distribution by Class within Each Amount Bin')
plt.xlabel('Amount Category')
plt.ylabel('Transaction Amount')
plt.legend(title='Class', labels=['Non-Fraud', 'Fraud'])
plt.show()

# %%
# Bar Chart: Count of Fraud vs Non-Fraud Transactions in Each Amount Bin
amount_bin_counts = df.groupby(['AmountCategory', 'Class']).size().unstack(fill_value=0)
amount_bin_counts.plot(kind='bar', stacked=True, figsize=(12, 6), color=['#3498db', '#e74c3c'])
plt.title('Count of Fraud vs Non-Fraud Transactions in Each Amount Bin')
plt.xlabel('Amount Category')
plt.ylabel('Count of Transactions')
plt.xticks(rotation=45)
plt.legend(title='Class', labels=['Non-Fraud', 'Fraud'])
plt.show()
# Out:
# <ipython-input-149-822d777bae4d>:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   amount_bin_counts = df.groupby(['AmountCategory', 'Class']).size().unstack(fill_value=0)

# %%
# Violin Plot: Distribution of Amounts for Fraud and Non-Fraud Transactions
plt.figure(figsize=(12, 6))
sns.violinplot(x='AmountCategory', y='Amount', hue='Class', data=df, split=True, palette=['#3498db', '#e74c3c'])
plt.title('Violin Plot of Transaction Amounts by Class within Each Amount Bin')
plt.xlabel('Amount Category')
plt.ylabel('Transaction Amount')
plt.legend(title='Class', labels=['Non-Fraud', 'Fraud'])
plt.show()

# %%
# Additional Analysis: Descriptive statistics for each amount category by Class
amount_category_stats = df.groupby(['AmountCategory', 'Class'])['Amount'].agg(['mean', 'median', 'std', 'count']).reset_index()
print("Descriptive Statistics for Transaction Amounts by Class and Amount Category:")
print(amount_category_stats)
# Out:
# Descriptive Statistics for Transaction Amounts by Class and Amount Category:
#    AmountCategory  Class         mean    median         std   count
# 0   Close to None      0    14.136370     9.990   13.612620  189399
# 1   Close to None      1     6.635836     1.000   11.449886     305
# 2        Very Low      0    71.824023    70.000   14.601281   37661
# 3        Very Low      1    87.637368    99.850   16.581008      57
# 4             Low      0   140.872968   138.000   28.200463   28025
# 5             Low      1   136.507111   125.300   31.317892      45
# 6          Medium      0   304.083833   285.700   80.818941   19773
# 7          Medium      1   315.419800   313.985   74.673637      50
# 8            High      0   676.629045   646.960  139.393620    6397
# 9            High      1   690.675769   718.765  126.248174      26
# 10      Very High      0  1666.220323  1394.600  759.065320    3005
# 11      Very High      1  1470.814444  1389.560  314.573264       9
# ...

# %% [markdown]
# # CROSS_ANALYSIS OF TIME AND AMOUNT

# %%
# Create bins for transaction time (in hours)
bins_time = [0, 6*3600, 12*3600, 18*3600, 24*3600]  # Bins for [0-6), [6-12), [12-18), [18-24)
labels_time = ['Night', 'Morning', 'Afternoon', 'Evening']
df['TimeCategory'] = pd.cut(df['Time'], bins=bins_time, labels=labels_time, right=False)

# %%
# Cross-tabulate Time intervals with Amount bins
cross_tab = pd.crosstab(df['TimeCategory'], df['AmountCategory'], values=df['Class'], aggfunc='sum').fillna(0)
cross_tab.columns.name = 'Amount Category'
cross_tab.index.name = 'Time Category'

print("Cross-tabulation of Time and Amount Categories (Fraud Counts):")
print(cross_tab)
# Out:
# Cross-tabulation of Time and Amount Categories (Fraud Counts):
# Amount Category  Close to None  Very Low  Low  Medium  High  Very High
# Time Category
# Night                       47         1    2       1     2          2
# Morning                     43        28   10       5     5          0
# Afternoon                   43         6    8      10     2          2
# Evening                     35         5    4      15     4          1

# %%
# Conditional Probability Analysis: Calculate probability of fraud for each combination
total_fraud_counts = df['Class'].sum()
probability_fraud = cross_tab.div(cross_tab.sum(axis=1), axis=0) * 100  # Convert to percentage

print("\nConditional Probability of Fraud for Time and Amount Combinations (%):")
print(probability_fraud)
# Out:
# Conditional Probability of Fraud for Time and Amount Combinations (%):
# Amount Category  Close to None   Very Low        Low     Medium      High  \
# Time Category
# Night                85.454545   1.818182   3.636364   1.818182  3.636364
# Morning              47.252747  30.769231  10.989011   5.494505  5.494505
# Afternoon            60.563380   8.450704  11.267606  14.084507  2.816901
# Evening              54.687500   7.812500   6.250000  23.437500  6.250000
#
# Amount Category  Very High
# Time Category
# Night             3.636364
# Morning           0.000000
# Afternoon         2.816901
# Evening           1.562500

# %%
# Visualization: Heatmap of Fraud Probability across Time and Amount Combinations
plt.figure(figsize=(10, 6))
sns.heatmap(probability_fraud, annot=True, fmt=".2f", cmap="YlGnBu", cbar_kws={'label': 'Probability of Fraud (%)'})
plt.title('Heatmap of Fraud Probability by Time and Amount Categories')
plt.xlabel('Amount Category')
plt.ylabel('Time Category')
plt.show()

# %%
# Grouped Bar Chart: Show fraud counts across different time and amount combinations
fraud_counts = cross_tab.copy()
fraud_counts.plot(kind='bar', stacked=True, figsize=(12, 6), color=['#3498db', '#e74c3c'])
plt.title('Fraud Counts by Time and Amount Categories')
plt.xlabel('Time Category')
plt.ylabel('Count of Fraudulent Transactions')
plt.xticks(rotation=45)
plt.legend(title='Amount Category')
plt.show()

# %%
# Additional Analysis: Descriptive statistics for fraud by Time and Amount categories
fraud_stats = df[df['Class'] == 1].groupby(['TimeCategory', 'AmountCategory'])['Amount'].agg(['mean', 'median', 'std', 'count']).reset_index()
print("\nDescriptive Statistics for Fraudulent Transactions by Time and Amount Categories:")
print(fraud_stats)
# Out:
# Descriptive Statistics for Fraudulent Transactions by Time and Amount Categories:
#    TimeCategory AmountCategory         mean    median         std  count
# 0         Night  Close to None     1.987021     1.000    4.549485     47
# 1         Night       Very Low    59.000000    59.000         NaN      1
# 2         Night            Low   184.220000   184.220    6.448814      2
# 3         Night         Medium   239.930000   239.930         NaN      1
# 4         Night           High   647.680000   647.680  167.838866      2
# 5         Night      Very High  1514.285000  1514.285  417.751615      2
# 6       Morning  Close to None     9.344884     1.520   12.656293     43
# 7       Morning       Very Low    94.066071    99.990   13.424735     28
# 8       Morning            Low   127.598000   115.315   25.845156     10
# 9       Morning         Medium   328.130000   340.110   96.136156      5
# 10      Morning           High   735.072000   730.860   59.610057      5
# ...
